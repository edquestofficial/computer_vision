# %%
! pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="D:/Trolly/data_set/data.yaml",
    epochs=50,
    imgsz=640,
    task="detect"
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.205 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.203  Python-3.13.3 torch-2.8.0+cpu CPU (Intel Core i5-10310U 1.70GHz)
# ...
